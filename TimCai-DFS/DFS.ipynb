# %%
from graphProblem import *
from search_algorithms import *
from search_algorithms_for_graph import *

# %%
nearguangzhoucity_node = [['Guangzhou', (113, 23)], ['Aomen',(113, 22)], ['Xianggang',(114, 22)],
        ['Nanning',(108, 22)], ['Changsha',(112, 28)], ['Nanchang',(115, 28)],
        ['Fuzhou',(119, 26)], ['Wuhan',(114, 30)], ['Hefei',(117, 31)],
        ['Nanjing',(118, 32)], ['Shanghai',(121, 31)], ['Hangzhou',(120, 30)],
        ['Guiyang',(106, 26)]]

# %%
print ('Node data: {}'.format(nearguangzhoucity_node))
# Out:
# Node data: [['Guangzhou', (113, 23)], ['Aomen', (113, 22)], ['Xianggang', (114, 22)], ['Nanning', (108, 22)], ['Changsha', (112, 28)], ['Nanchang', (115, 28)], ['Fuzhou', (119, 26)], ['Wuhan', (114, 30)], ['Hefei', (117, 31)], ['Nanjing', (118, 32)], ['Shanghai', (121, 31)], ['Hangzhou', (120, 30)], ['Guiyang', (106, 26)]]

# %%
nearguangzhoucity_neighbour = [['Guangzhou',[['Nanchang',671], ['Xianggang',119], ['Aomen',108],['Fuzhou',693]]],
        ['Nanchang',[['Hefei',373],['Wuhan',260],['Fuzhou',447],['Hangzhou',453],['Changsha',290]]],
        ['Hefei',[['Wuhan',310], ['Nanjing',151]]],
        ['Nanjing',[['Shanghai',270]]],
        ['Shanghai',[['Hangzhou',165]]],
        ['Hangzhou',[['Fuzhou',475]]],
        ['Fuzhou',[['Xianggang',666]]],
        ['Xianggang',[['Aomen',62]]],
        ['Aomen',[['Nanning',537]]],
        ['Nanning',[['Guiyang',461], ['Changsha',758]]],
        ['Changsha',[['Wuhan',295], ['Guangzhou',569]]]]

# %%
print ('Node neighbour data: {}'.format(nearguangzhoucity_neighbour))
# Out:
# Node neighbour data: [['Guangzhou', [['Nanchang', 671], ['Xianggang', 119], ['Aomen', 108], ['Fuzhou', 693]]], ['Nanchang', [['Hefei', 373], ['Wuhan', 260], ['Fuzhou', 447], ['Hangzhou', 453], ['Changsha', 290]]], ['Hefei', [['Wuhan', 310], ['Nanjing', 151]]], ['Nanjing', [['Shanghai', 270]]], ['Shanghai', [['Hangzhou', 165]]], ['Hangzhou', [['Fuzhou', 475]]], ['Fuzhou', [['Xianggang', 666]]], ['Xianggang', [['Aomen', 62]]], ['Aomen', [['Nanning', 537]]], ['Nanning', [['Guiyang', 461], ['Changsha', 758]]], ['Changsha', [['Wuhan', 295], ['Guangzhou', 569]]]]

# %%
nearguangzhoucity_graph_data, nearguangzhoucity_graph = define_graph(nearguangzhoucity_neighbour, nearguangzhoucity_node, True)

# %%
show_graph(nearguangzhoucity_graph_data)

# %%
nearguangzhoucity_problem = GraphProblem('Guiyang', 'Shanghai', nearguangzhoucity_graph)

# %%
display(nearguangzhoucity_problem, DFS_graph())
# Out:
# Algorithm: DFS_graph
#  Iteration times : 32  Path : [<Node Guiyang>, <Node Nanning>, <Node Aomen>, <Node Xianggang>, <Node Fuzhou>, <Node Hangzhou>, <Node Shanghai>]

# %%
display_for_graph(nearguangzhoucity_problem, DFS_graph_for_graph(), nearguangzhoucity_graph_data)
# Out:
# Algorithm: DFS_graph_for_graph
# interactive(children=(IntSlider(value=0, description='iteration', max=1), Output()), _dom_classes=('widget-int…
# interactive(children=(ToggleButton(value=False, description='Visualize'), Output()), _dom_classes=('widget-int…
